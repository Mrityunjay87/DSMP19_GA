# %%
temp=[{"createdTime":1549544387000,"frhSwapTask":{"createdTime":1549544387000,"id":111,"modifiedTime":1582808827000,"name":"Wideband_ATP_11A","site":{"additionalInformation":"test","address":{"addressLine1":"Test Site Address","addressLine2":"","latitude":"25.00000","longitude":"54.00000","measuredLatitude":"19.1252163","measuredLongitude":"73.0136021"},"assignedId":"Y-MU-MUMB-ENB-2977","backhaul":"Not_Specified","cabinettype":"In_Building","city":"DSF","clutterType":"Not_Specified","dataFacilityType":"Not_Specified","duTypeATP11A":"DU","eNodeBType":"Macro","govCircle":{"id":2,"name":"Mumbai","zone":"West"},"id":324714,"modifiedTime":1560439804000,"name":"Test Site","sapId":"Y-MU-MUMB-ENB-2977","sitecategory":"GBT","sitetype":"Shared","stage":"Work_In_Progress","status":"eNodeB_Installed","wifiAvailable":true,"workOrder":{"plannedCompletionDate":"2017-07-20"}},"soStatus":"Not Tried","status":"Assigned_To_Field_Engineer","totalDeInstallRRH":2},"id":247,"isSectorSwapped":false,"modifiedTime":1582806837000,"rrhType":"RFD01P_03","rrhTypeRemark":"","sector":{"name":"ALPHA","sectorNumber":"1"},"site":{"additionalInformation":"test","address":{"addressLine1":"Test Site Address","addressLine2":"","latitude":"25.00000","longitude":"54.00000","measuredLatitude":"19.1252163","measuredLongitude":"73.0136021"},"assignedId":"Y-MU-MUMB-ENB-2977","backhaul":"Not_Specified","cabinettype":"In_Building","city":"DSF","clutterType":"Not_Specified","dataFacilityType":"Not_Specified","duTypeATP11A":"DU","eNodeBType":"Macro","govCircle":{"id":2,"name":"Mumbai","zone":"West"},"id":324714,"modifiedTime":1560439804000,"name":"Test Site","sapId":"Y-MU-MUMB-ENB-2977","sitecategory":"GBT","sitetype":"Shared","stage":"Work_In_Progress","status":"eNodeB_Installed","wifiAvailable":true,"workOrder":{"plannedCompletionDate":"2017-07-20"}}},{"createdTime":1549544387000,"frhSwapTask":{"createdTime":1549544387000,"id":111,"modifiedTime":1582808827000,"name":"Wideband_ATP_11A","site":{"additionalInformation":"test","address":{"addressLine1":"Test Site Address","addressLine2":"","latitude":"25.00000","longitude":"54.00000","measuredLatitude":"19.1252163","measuredLongitude":"73.0136021"},"assignedId":"Y-MU-MUMB-ENB-2977","backhaul":"Not_Specified","cabinettype":"In_Building","city":"DSF","clutterType":"Not_Specified","dataFacilityType":"Not_Specified","duTypeATP11A":"DU","eNodeBType":"Macro","govCircle":{"id":2,"name":"Mumbai","zone":"West"},"id":324714,"modifiedTime":1560439804000,"name":"Test Site","sapId":"Y-MU-MUMB-ENB-2977","sitecategory":"GBT","sitetype":"Shared","stage":"Work_In_Progress","status":"eNodeB_Installed","wifiAvailable":true,"workOrder":{"plannedCompletionDate":"2017-07-20"}},"soStatus":"Not Tried","status":"Assigned_To_Field_Engineer","totalDeInstallRRH":2},"id":248,"isSectorSwapped":true,"modifiedTime":1582806837000,"rrhType":"RF41_03B","rrhTypeRemark":"","sector":{"name":"BETA","sectorNumber":"2"},"site":{"additionalInformation":"test","address":{"addressLine1":"Test Site Address","addressLine2":"","latitude":"25.00000","longitude":"54.00000","measuredLatitude":"19.1252163","measuredLongitude":"73.0136021"},"assignedId":"Y-MU-MUMB-ENB-2977","backhaul":"Not_Specified","cabinettype":"In_Building","city":"DSF","clutterType":"Not_Specified","dataFacilityType":"Not_Specified","duTypeATP11A":"DU","eNodeBType":"Macro","govCircle":{"id":2,"name":"Mumbai","zone":"West"},"id":324714,"modifiedTime":1560439804000,"name":"Test Site","sapId":"Y-MU-MUMB-ENB-2977","sitecategory":"GBT","sitetype":"Shared","stage":"Work_In_Progress","status":"eNodeB_Installed","wifiAvailable":true,"workOrder":{"plannedCompletionDate":"2017-07-20"}}},{"createdTime":1549544388000,"frhSwapTask":{"createdTime":1549544387000,"id":111,"modifiedTime":1582808827000,"name":"Wideband_ATP_11A","site":{"additionalInformation":"test","address":{"addressLine1":"Test Site Address","addressLine2":"","latitude":"25.00000","longitude":"54.00000","measuredLatitude":"19.1252163","measuredLongitude":"73.0136021"},"assignedId":"Y-MU-MUMB-ENB-2977","backhaul":"Not_Specified","cabinettype":"In_Building","city":"DSF","clutterType":"Not_Specified","dataFacilityType":"Not_Specified","duTypeATP11A":"DU","eNodeBType":"Macro","govCircle":{"id":2,"name":"Mumbai","zone":"West"},"id":324714,"modifiedTime":1560439804000,"name":"Test Site","sapId":"Y-MU-MUMB-ENB-2977","sitecategory":"GBT","sitetype":"Shared","stage":"Work_In_Progress","status":"eNodeB_Installed","wifiAvailable":true,"workOrder":{"plannedCompletionDate":"2017-07-20"}},"soStatus":"Not Tried","status":"Assigned_To_Field_Engineer","totalDeInstallRRH":2},"id":249,"isSectorSwapped":false,"modifiedTime":1582800234000,"rrhTypeRemark":"","sector":{"name":"GAMMA","sectorNumber":"3"},"site":{"additionalInformation":"test","address":{"addressLine1":"Test Site Address","addressLine2":"","latitude":"25.00000","longitude":"54.00000","measuredLatitude":"19.1252163","measuredLongitude":"73.0136021"},"assignedId":"Y-MU-MUMB-ENB-2977","backhaul":"Not_Specified","cabinettype":"In_Building","city":"DSF","clutterType":"Not_Specified","dataFacilityType":"Not_Specified","duTypeATP11A":"DU","eNodeBType":"Macro","govCircle":{"id":2,"name":"Mumbai","zone":"West"},"id":324714,"modifiedTime":1560439804000,"name":"Test Site","sapId":"Y-MU-MUMB-ENB-2977","sitecategory":"GBT","sitetype":"Shared","stage":"Work_In_Progress","status":"eNodeB_Installed","wifiAvailable":true,"workOrder":{"plannedCompletionDate":"2017-07-20"}}}]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-6670457b282f> in <module>
# ...
